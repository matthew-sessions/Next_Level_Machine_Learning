# %%
import csv

# %%
class City:
    def __init__(self, name, lat, lon):
      self.name = name
      self.lat = lat
      self.lon = lon
    def __str__(self):
      return(f"{self.name}, Lon: {self.lon}, Lat: {self.lat}")
    
cities = []

# %%
def cityreader(cities=[]):
  # TODO Implement the functionality to read from the 'cities.csv' file
  # For each city record, create a new City instance and add it to the 
  # `cities` list
    with open('cities.csv', 'r') as csvfile:

        csvreader = csv.reader(csvfile)

        next(csvreader)

        for i in csvreader:
            cities.append(City(i[0], i[3], i[4]))   
    return cities

# %%
cities = cityreader(cities)

# Print the list of cities (name, lat, lon), 1 record per line.
for c in cities:
    print(c)
# Out:
# Seattle, Lon: -122.3238, Lat: 47.6217
# Richmond, Lon: -77.4755, Lat: 37.5294
# Virginia Beach, Lon: -76.0435, Lat: 36.7335
# Washington, Lon: -77.0163, Lat: 38.9047
# Milwaukee, Lon: -87.9669, Lat: 43.0640
# Orlando, Lon: -81.3448, Lat: 28.4801
# Miami, Lon: -80.2102, Lat: 25.7840
# Tampa, Lon: -82.4454, Lat: 27.9937
# Jacksonville, Lon: -81.6749, Lat: 30.3322
# Albuquerque, Lon: -106.6476, Lat: 35.1055
# Fort Worth, Lon: -97.3466, Lat: 32.7813
# McAllen, Lon: -98.2457, Lat: 26.2203
# El Paso, Lon: -106.4310, Lat: 31.8478
# Dallas, Lon: -96.7659, Lat: 32.7938
# Austin, Lon: -97.7545, Lat: 30.3038
# Houston, Lon: -95.3936, Lat: 29.7871
# San Antonio, Lon: -98.5247, Lat: 29.4722
# New Orleans, Lon: -89.9288, Lat: 30.0687
# Charlotte, Lon: -80.8308, Lat: 35.2080
# Raleigh, Lon: -78.6441, Lat: 35.8323
# Omaha, Lon: -96.0453, Lat: 41.2634
# Memphis, Lon: -89.9773, Lat: 35.1047
# Nashville, Lon: -86.7844, Lat: 36.1714
# Buffalo, Lon: -78.8487, Lat: 42.9016
# Queens, Lon: -73.7976, Lat: 40.7498
# New York, Lon: -73.9249, Lat: 40.6943
# Bronx, Lon: -73.8662, Lat: 40.8501
# Brooklyn, Lon: -73.9496, Lat: 40.6501
# Manhattan, Lon: -73.9662, Lat: 40.7834
# Philadelphia, Lon: -75.1340, Lat: 40.0076
# Pittsburgh, Lon: -79.9763, Lat: 40.4396
# Sacramento, Lon: -121.4683, Lat: 38.5666
# Riverside, Lon: -117.3949, Lat: 33.9382
# San Francisco, Lon: -122.4429, Lat: 37.7561
# San Diego, Lon: -117.1225, Lat: 32.8312
# San Jose, Lon: -121.8488, Lat: 37.3020
# Los Angeles, Lon: -118.4068, Lat: 34.1140
# Las Vegas, Lon: -115.2603, Lat: 36.2288
# Denver, Lon: -104.8759, Lat: 39.7621
# Chicago, Lon: -87.6861, Lat: 41.8373
# Atlanta, Lon: -84.4231, Lat: 33.7627
# Indianapolis, Lon: -86.1458, Lat: 39.7771
# Oklahoma City, Lon: -97.5138, Lat: 35.4677
# Phoenix, Lon: -112.0891, Lat: 33.5722
# Tucson, Lon: -110.8777, Lat: 32.1558
# Bridgeport, Lon: -73.1958, Lat: 41.1909
# Hartford, Lon: -72.6834, Lat: 41.7661
# Baltimore, Lon: -76.6144, Lat: 39.3051
# Boston, Lon: -71.0838, Lat: 42.3189
# Cleveland, Lon: -81.6805, Lat: 41.4766
# Columbus, Lon: -82.9852, Lat: 39.9859
# Cincinnati, Lon: -84.5060, Lat: 39.1412
# Salt Lake City, Lon: -111.9301, Lat: 40.7774
# Saint Louis, Lon: -90.2451, Lat: 38.6358
# Kansas City, Lon: -94.5541, Lat: 39.1239
# Minneapolis, Lon: -93.2679, Lat: 44.9635
# Detroit, Lon: -83.1024, Lat: 42.3834
# Providence, Lon: -71.4186, Lat: 41.8229
# Louisville, Lon: -85.6488, Lat: 38.1662
# Portland, Lon: -122.6500, Lat: 45.5372

# %%
with open('cities.csv', 'r') as csvfile:

    csvreader = csv.reader(csvfile)

    next(csvreader)

    for row in csvreader:
        print(row[4])
# Out:
# -122.3238
# -77.4755
# -76.0435
# -77.0163
# -87.9669
# -81.3448
# -80.2102
# -82.4454
# -81.6749
# -106.6476
# -97.3466
# -98.2457
# -106.4310
# -96.7659
# -97.7545
# -95.3936
# -98.5247
# -89.9288
# -80.8308
# -78.6441
# -96.0453
# -89.9773
# -86.7844
# -78.8487
# -73.7976
# -73.9249
# -73.8662
# -73.9496
# -73.9662
# -75.1340
# -79.9763
# -121.4683
# -117.3949
# -122.4429
# -117.1225
# -121.8488
# -118.4068
# -115.2603
# -104.8759
# -87.6861
# -84.4231
# -86.1458
# -97.5138
# -112.0891
# -110.8777
# -73.1958
# -72.6834
# -76.6144
# -71.0838
# -81.6805
# -82.9852
# -84.5060
# -111.9301
# -90.2451
# -94.5541
# -93.2679
# -83.1024
# -71.4186
# -85.6488
# -122.6500
