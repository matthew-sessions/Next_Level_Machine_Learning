# %%
import sklearn
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import numpy as np

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)
plt.scatter(x,y);

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)

model.fit(x.reshape(-1,1), y)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit.reshape(-1,1))

plt.scatter(x, y)
plt.plot(xfit, yfit);

# %%
print('Slope:  ', model.coef_[0])
print('Intercept:  ', model.intercept_)
# Out:
# Slope:   2.027208810360695
# Intercept:   -4.998577085553202

# %%
x2 = 10 * rng.rand(100,2)
y2 = .5 + np.dot(x2, [1.5, -2])

# %%
model.fit(x2, y2)
print(model.coef_)
print(model.intercept_)
# Out:
# [ 1.5 -2. ]
# 0.4999999999999978

# %%
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x2[:,0], x2[:,1], y2, c='skyblue', s=60)
ax.view_init(30, 185)
plt.show()

# %%
import pandas as pd

df = pd.DataFrame([[1,2,3,4,5], [11,22,36,45,51], [3,4,6,9,12], [5,6,7,8,9]], columns=['a', 'b', 'c', 'd','g'])
df.head()
# Out:
#     a   b   c   d   g
# 0   1   2   3   4   5
# 1  11  22  36  45  51
# 2   3   4   6   9  12
# 3   5   6   7   8   9

# %%
model.fit(df[['a', 'b', 'c', 'd']].values, df.g.values)

print('Slope:  ', model.coef_)
print('Intercept:  ', model.intercept_)
model.predict([[1,2,3,4]])
# Out:
# Slope:   [ 0.51589595 -0.75578035 -0.64017341  1.8800578 ]
# Intercept:   0.395953757225449
# array([5.])

# %%
class SimpleLinearRegression:
    def __init__(self):
        pass
    def fit(self, X, y):
        self.centriod_x = sum(X) / len(X)
        self.centriod_y = sum(y) / len(y)

# %%
model = SimpleLinearRegression()

# %%
model.fit([1,2,3], [2,3])

# %%
model.centriod_x
# Out:
# 6

# %%
m = LinearRegression(df[['a', 'b', 'c', 'd']].values, df.g.values)

# %%
np.size(df[['a', 'b', 'c', 'd']].values.tolist(), 1)
# Out:
# 4

# %%
str(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-a69d9fc85d63> in <module>
# ----> 1 str(5)
#
# TypeError: 'str' object is not callable

# %%
del str

# %%
str(5)
# Out:
# '5'
